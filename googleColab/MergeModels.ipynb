# %%
# !pip uninstall -y peft
# !pip install git+https://github.com/huggingface/peft.git@v0.7.1
# Out:
# Found existing installation: peft 0.7.1
# Uninstalling peft-0.7.1:
#   Successfully uninstalled peft-0.7.1
# Collecting git+https://github.com/huggingface/peft.git@v0.7.1
#   Cloning https://github.com/huggingface/peft.git (to revision v0.7.1) to /tmp/pip-req-build-4kwqvse5
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft.git /tmp/pip-req-build-4kwqvse5
#   Running command git checkout -q de961f3c69b05c0767a7b0d3a665c8b432e4331a
#   Resolved https://github.com/huggingface/peft.git to commit de961f3c69b05c0767a7b0d3a665c8b432e4331a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from peft==0.7.1) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.7.1) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft==0.7.1) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft==0.7.1) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.7.1) (2.6.0+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from peft==0.7.1) (4.52.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from peft==0.7.1) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.7.1) (1.7.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft==0.7.1) (0.5.3)
# Requirement already satisfied: huggingface_hub>=0.17.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.7.1) (0.31.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.17.0->peft==0.7.1) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.17.0->peft==0.7.1) (2025.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.17.0->peft==0.7.1) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.17.0->peft==0.7.1) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft==0.7.1) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->peft==0.7.1) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->peft==0.7.1) (0.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft==0.7.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.17.0->peft==0.7.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.17.0->peft==0.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.17.0->peft==0.7.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.17.0->peft==0.7.1) (2025.4.26)
# Building wheels for collected packages: peft
#   Building wheel for peft (pyproject.toml) ... done
#   Created wheel for peft: filename=peft-0.7.1-py3-none-any.whl size=168342 sha256=2438d01e790dc238cf7570ceb1e681f00d823ca3c07b560f47f0d44fa464ca88
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k5mrpwho/wheels/4f/6c/34/1dcaed03a9ceeefadc527983d011ad419042e5405034f4e6bc
# Successfully built peft
# Installing collected packages: peft
# Successfully installed peft-0.7.1

# %%
import json
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer
from huggingface_hub import login

# Montar directorio de drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# LLAMA

# %%
# Ruta del archivo
adapter_config_path = "/content/drive/MyDrive/Colab Notebooks/ft_llama_model/final_model/llama-1b_prompt0_60_PreprocesadoES/adapter_config.json"

# Cargar, limpiar y guardar
with open(adapter_config_path, "r") as f:
    config = json.load(f)

# Eliminar el campo problemático
if "use_rslora" in config:
    del config["use_rslora"]

# Sobrescribir el archivo limpio
with open(adapter_config_path, "w") as f:
    json.dump(config, f, indent=4)

# %%
# Ruta del modelo base y del adaptador LoRA
base_model_id = "meta-llama/Llama-3.2-1B-Instruct"
adapter_path = "/content/drive/MyDrive/Colab Notebooks/ft_llama_model/final_model/llama-1b_prompt0_60_PreprocesadoES"  # cambia esto

# Montar directorio de drive
from google.colab import drive
drive.mount('/content/drive')

# Token de Hugging Face
hf_token = "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"
login(hf_token)

# 1. Cargar el modelo base
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    device_map="auto",
    torch_dtype="auto"
)

# 2. Cargar el adaptador sobre el modelo base
model = PeftModel.from_pretrained(model, adapter_path)

# 3. Fusionar manualmente los pesos del adaptador con el modelo base
model = model.merge_and_unload()

# 4. Guardar el modelo final completo (sin LoRA, ya fusionado)
output_path = "/content/drive/MyDrive/Colab Notebooks/ft_llama_model/final_model/llama_merged"
model.save_pretrained(output_path)

tokenizer = AutoTokenizer.from_pretrained(base_model_id)
tokenizer.save_pretrained(output_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-939ca13bce5d> in <cell line: 0>()
#       5 # Montar directorio de drive
#       6 from google.colab import drive
# ----> 7 drive.mount('/content/drive')
#       8
#       9 # Token de Hugging Face
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     257
#     258   while True:
# --> 259     case = d.expect([
#     260         success,
#     261         prompt,
#
# /usr/local/lib/python3.11/dist-packages/pexpect/spawnbase.py in expect(self, pattern, timeout, searchwindowsize, async_, **kw)
#     352
#     353         compiled_pattern_list = self.compile_pattern_list(pattern)
# --> 354         return self.expect_list(compiled_pattern_list,
#     355                 timeout, searchwindowsize, async_)
#     356
#
# /usr/local/lib/python3.11/dist-packages/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     381             return expect_async(exp, timeout)
#     382         else:
# --> 383             return exp.expect_loop(timeout)
#     384
#     385     def expect_exact(self, pattern_list, timeout=-1, searchwindowsize=-1,
#
# /usr/local/lib/python3.11/dist-packages/pexpect/expect.py in expect_loop(self, timeout)
#     169                 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170                 if self.spawn.delayafterread is not None:
# --> 171                     time.sleep(self.spawn.delayafterread)
#     172                 idx = self.new_data(incoming)
#     173                 # Keep reading until exception or return.
#
# KeyboardInterrupt:

# %% [markdown]
# FALCON

# %%
# Ruta del archivo
adapter_config_path = "/content/drive/MyDrive/Colab Notebooks/ft_falcon_model/final_model/falcon-7b_prompt0_60_epoch120_PreprocesadoES/adapter_config.json"

# Cargar, limpiar y guardar
with open(adapter_config_path, "r") as f:
    config = json.load(f)

# Eliminar el campo problemático
if "use_rslora" in config:
    del config["use_rslora"]

# Sobrescribir el archivo limpio
with open(adapter_config_path, "w") as f:
    json.dump(config, f, indent=4)

# %%
# Ruta del modelo base y del adaptador LoRA
base_model_id = "tiiuae/falcon-7b"
adapter_path = "/content/drive/MyDrive/Colab Notebooks/ft_falcon_model/final_model/falcon-7b_prompt0_60_epoch120_PreprocesadoES"

# Montar directorio de drive
from google.colab import drive
drive.mount('/content/drive')

# Token de Hugging Face
# hf_token = "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"
# login(hf_token)

# 1. Cargar el modelo base
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    device_map="auto",
    torch_dtype="auto"
)

# 2. Cargar el adaptador sobre el modelo base
model = PeftModel.from_pretrained(model, adapter_path)

# 3. Fusionar manualmente los pesos del adaptador con el modelo base
model = model.merge_and_unload()

# 4. Guardar el modelo final completo (sin LoRA, ya fusionado)
output_path = "/content/drive/MyDrive/Colab Notebooks/ft_falcon_model/final_model/falcon_merged"
model.save_pretrained(output_path)

tokenizer = AutoTokenizer.from_pretrained(base_model_id)
tokenizer.save_pretrained(output_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/17.7k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.48G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# ('/content/drive/MyDrive/Colab Notebooks/ft_falcon_model/final_model/falcon_merged/tokenizer_config.json',
#  '/content/drive/MyDrive/Colab Notebooks/ft_falcon_model/final_model/falcon_merged/special_tokens_map.json',
#  '/content/drive/MyDrive/Colab Notebooks/ft_falcon_model/final_model/falcon_merged/tokenizer.json')
